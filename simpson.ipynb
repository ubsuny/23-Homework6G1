# %% [markdown]
# <a href="https://colab.research.google.com/github/JustinJaniszewski/23-Homework6G1/blob/patch1/simpson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import calculus as calc
import matplotlib.pyplot as plt
import numpy as np

# %%
GROUP_NUMBER = 1 # specifing our group number

# defining our functions
def exp_func(x):
  return np.exp(-1 / np.where(np.isclose(x, 0), 1e-8, x))

def cos_func(x):
  return np.cos(1 / np.where(np.isclose(x, 0), 1e-8, x))

def cube_func(x):
  return x**3 + 1 / GROUP_NUMBER

# %%
# integral of exp(-1/x)

# plotting graph using first set of bounds
lower_bound = 0
upper_bound = 10*GROUP_NUMBER
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = exp_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of e^(-1/x) (0 to 10)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(exp_func, lower_bound, upper_bound,10) # value of integral from 0 to 10
# Out:
# 7.264297481368504

# %%
# plotting graph using second set of bounds
lower_bound = 0
upper_bound = np.pi*GROUP_NUMBER
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = exp_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of e^(-1/x)  (0 to pi)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(exp_func, lower_bound, upper_bound,10) # value of integral from 0 to pi
# Out:
# 1.421105251831652

# %%
# plotting graph using third set of bounds
lower_bound = -1
upper_bound = 1
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = exp_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of e^(-1/x)  (-1 to 1)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(exp_func, lower_bound, upper_bound,10) # value of integral from -1 to 1
# Out:
# 25.003892901999663

# %%
# integral of cos(1/x)
# plotting graph using first set of bounds
lower_bound = 0
upper_bound = 10*GROUP_NUMBER
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = cos_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of cos(1/x) (0 to 10)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(cos_func, lower_bound, upper_bound,10) # value of integral from 0 to 10 for cos function
# Out:
# 8.69239374558246

# %%
# plotting cos(1/x) using second set of bounds
lower_bound = 0
upper_bound = np.pi*GROUP_NUMBER
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = cos_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of cos(1/x)  (0 to pi)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(cos_func, lower_bound, upper_bound,10) # value of integral from 0 to pi for cos function
# Out:
# 1.469312962980345

# %%
# plotting cos(1/x) using third set of bounds
lower_bound = -1
upper_bound = 1
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = cos_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of cos(1/x)  (-1 to 1)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(cos_func, lower_bound, upper_bound,10) # value of integral from -1 to 1 for cos function
# Out:
# -0.23385008140696048

# %%
# integral of x^3 + 1
# plotting graph using first set of bounds
lower_bound = 0
upper_bound = 10*GROUP_NUMBER
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = cube_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of x^3 +1 (0 to 10)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(cube_func, lower_bound, upper_bound,10) # value of integral from 0 to 10 for cube function
# Out:
# 2510.0

# %%
# plotting x^3 + 1 using second set of bounds
lower_bound = 0
upper_bound = np.pi*GROUP_NUMBER
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = cube_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of x^3 +1 (0 to pi)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(cube_func, lower_bound, upper_bound,10) # value of integral from 0 to pi for cube function
# Out:
# 27.4938654120904

# %%
# plotting x^3 + 1 using third set of bounds
lower_bound = -1
upper_bound = 1
x_vals = np.linspace(lower_bound, upper_bound, 100)
y_vals = cube_func(x_vals)
plt.plot(x_vals,y_vals)
plt.fill_between(x_vals, y_vals, alpha = 0.5)
plt.title("Integral of x^3 + 1  (-1 to 1)")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
calc.simpson(cube_func, lower_bound, upper_bound,10) # value of integral from -1 to 1for cube function
# Out:
# 2.0
